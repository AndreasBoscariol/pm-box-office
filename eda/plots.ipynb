# %% [markdown]
# # Plotting Dataset Prep
#
# Build the three plotting grains first: one row per movie, one row per movie-day, and one row per calendar weekend. Keep charts downstream of these dataframes so the notebook does not force one time-series workflow onto a mixed forecasting problem.
